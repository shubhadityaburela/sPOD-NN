# %%
import numpy as np
import matplotlib.pyplot as plt
from Helper import save_fig
import pandas as pd
import os

impath = "../plots/"
os.makedirs(impath, exist_ok=True) 

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern"]})

SMALL_SIZE = 16   # 16
MEDIUM_SIZE = 18   # 18
BIGGER_SIZE = 20   # 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# Out:
# /var/folders/ys/rspl6b551rl9f5w6r8yffqv40000gn/T/ipykernel_83322/1007113044.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
beta = np.asarray([542, 544, 546, 548, 552, 554, 556, 558, 562, 564, 566, 568, 572, 574, 576, 578])

err_sPOD_T_1D = np.asarray([0.061, 0.089, 0.093, 0.070, 0.066, 0.059, 0.059, 0.059, 0.059, 0.064, 0.056, 0.046, 0.047, 0.076, 0.085, 0.067])
err_I_T_1D = np.asarray([0.048, 0.073, 0.073, 0.048, 0.045, 0.069, 0.069, 0.045, 0.044, 0.067, 0.067, 0.044, 0.047, 0.071, 0.071, 0.047])
err_POD_T_1D = np.asarray([0.140, 0.138, 0.137, 0.136, 0.136, 0.136, 0.136, 0.136, 0.136, 0.136, 0.136, 0.136, 0.136, 0.136, 0.136, 0.136])

err_sPOD_T_2D = np.asarray([0.058, 0.081, 0.084, 0.086, 0.059, 0.082, 0.072, 0.041, 0.060, 0.083, 0.076, 0.051, 0.063, 0.091, 0.146, 0.133])
err_I_T_2D = np.asarray([0.050, 0.074, 0.075, 0.050, 0.048, 0.073, 0.074, 0.049, 0.048, 0.072, 0.073, 0.048, 0.047, 0.059, 0.071, 0.047])
err_POD_T_2D = np.asarray([0.283, 0.281, 0.278, 0.277, 0.275, 0.275, 0.275, 0.275, 0.276, 0.277, 0.278, 0.279, 0.280, 0.281, 0.282, 0.282])

err_sPOD_T_2DNL = np.asarray([0.080, 0.077, 0.074, 0.072, 0.071, 0.073, 0.073, 0.074, 0.073, 0.072, 0.070, 0.069, 0.071, 0.074, 0.078, 0.079])
err_I_T_2DNL = np.asarray([0.069, 0.067, 0.066, 0.064, 0.064, 0.065, 0.065, 0.064, 0.063, 0.062, 0.060, 0.058, 0.060, 0.062, 0.063, 0.066])
err_POD_T_2DNL = np.asarray([0.188, 0.186, 0.184, 0.183, 0.182, 0.180, 0.180, 0.180, 0.180, 0.180, 0.181, 0.182, 0.183, 0.185, 0.186, 0.189])

err_sPOD_S_1D = np.asarray([0.014, 0.017, 0.016, 0.011, 0.013, 0.017, 0.014, 0.010, 0.011, 0.014, 0.013, 0.009, 0.011, 0.015, 0.015, 0.011])
err_I_S_1D = np.asarray([0.012, 0.015, 0.015, 0.010, 0.011, 0.015, 0.015, 0.010, 0.010, 0.014, 0.014, 0.010, 0.010, 0.015, 0.015, 0.010])
err_POD_S_1D = np.asarray([0.048, 0.047, 0.047, 0.047, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046, 0.046])

err_sPOD_S_2D = np.asarray([0.012, 0.016, 0.015, 0.011, 0.011, 0.015, 0.015, 0.012, 0.010, 0.014, 0.015, 0.013, 0.013, 0.018, 0.022, 0.016])
err_I_S_2D = np.asarray([0.013, 0.018, 0.018, 0.013, 0.012, 0.017, 0.017, 0.012, 0.012, 0.017, 0.017, 0.012, 0.012, 0.014, 0.016, 0.012])
err_POD_S_2D = np.asarray([0.052, 0.052, 0.051, 0.051, 0.050, 0.050, 0.050, 0.050, 0.050, 0.050, 0.050, 0.050, 0.049, 0.049, 0.049, 0.049])

err_sPOD_S_2DNL = np.asarray([0.019, 0.018, 0.018, 0.018, 0.019, 0.019, 0.019, 0.019, 0.018, 0.017, 0.017, 0.016, 0.015, 0.016, 0.016, 0.018])
err_I_S_2DNL = np.asarray([0.018, 0.017, 0.017, 0.017, 0.018, 0.018, 0.018, 0.018, 0.017, 0.017, 0.016, 0.015, 0.015, 0.015, 0.016, 0.017])
err_POD_S_2DNL = np.asarray([0.031, 0.030, 0.029, 0.028, 0.027, 0.027, 0.026, 0.026, 0.026, 0.027, 0.027, 0.027, 0.028, 0.029, 0.029, 0.030])

# %%
fig = plt.figure(figsize=(14, 10), constrained_layout=True)
(subfig_t, subfig_b) = fig.subfigures(2, 1, hspace=0.05, wspace=0.1)

gs_t = subfig_t.add_gridspec(nrows=1, ncols=4)
ax1 = subfig_t.add_subplot(gs_t[0, 1:3])

ax1.plot(beta, err_sPOD_T_1D, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}$")
ax1.plot(beta, err_I_T_1D, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}$")
ax1.plot(beta, err_POD_T_1D, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}$")
ax1.set_title("Temperature (1D without wind)")
ax1.grid()
ax1.legend(loc='upper right', bbox_to_anchor=(0.90,0.7))



gs_b = subfig_b.add_gridspec(nrows=1, ncols=4)
ax2 = subfig_b.add_subplot(gs_b[0, 0:2])
ax3 = subfig_b.add_subplot(gs_b[0, 2:4], sharex=ax2)

ax2.plot(beta, err_sPOD_T_2D, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}$")
ax2.plot(beta, err_I_T_2D, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}$")
ax2.plot(beta, err_POD_T_2D, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}$")
ax2.set_title("Temperature (2D without wind)")
ax2.grid()
ax2.legend(loc='upper right', bbox_to_anchor=(0.99,0.9))

ax3.plot(beta, err_sPOD_T_2DNL, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}$")
ax3.plot(beta, err_I_T_2DNL, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}$")
ax3.plot(beta, err_POD_T_2DNL, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}$")
ax3.set_title("Temperature (2D with wind)")
ax3.grid()
ax3.legend(loc='center right', bbox_to_anchor=(0.95,0.6))


fig.supxlabel(r"$\mu$")
fig.supylabel("Error")

fig.savefig(impath + "Parameter_sweep_study_T" + ".png", format='png',dpi=200, transparent=True)
fig.savefig(impath + "Parameter_sweep_study_T" + ".pdf", format='pdf',dpi=200, transparent=True, bbox_inches="tight")

# %%
fig = plt.figure(figsize=(14, 10), constrained_layout=True)
(subfig_t, subfig_b) = fig.subfigures(2, 1, hspace=0.05, wspace=0.1)

gs_t = subfig_t.add_gridspec(nrows=1, ncols=4)
ax1 = subfig_t.add_subplot(gs_t[0, 1:3])

ax1.plot(beta, err_sPOD_S_1D, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}$")
ax1.plot(beta, err_I_S_1D, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}$")
ax1.plot(beta, err_POD_S_1D, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}$")
ax1.set_title("Supply mass fraction (1D without wind)")
ax1.grid()
ax1.legend(loc='upper right', bbox_to_anchor=(0.95,0.8))



gs_b = subfig_b.add_gridspec(nrows=1, ncols=4)
ax2 = subfig_b.add_subplot(gs_b[0, 0:2])
ax3 = subfig_b.add_subplot(gs_b[0, 2:4], sharex=ax2)

ax2.plot(beta, err_sPOD_S_2D, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}$")
ax2.plot(beta, err_I_S_2D, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}$")
ax2.plot(beta, err_POD_S_2D, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}$")
ax2.set_title("Supply mass fraction (2D without wind)")
ax2.grid()
ax2.legend(loc='upper right', bbox_to_anchor=(0.99,0.9))

ax3.plot(beta, err_sPOD_S_2DNL, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}$")
ax3.plot(beta, err_I_S_2DNL, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}$")
ax3.plot(beta, err_POD_S_2DNL, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}$")
ax3.set_title("Supply mass fraction (2D with wind)")
ax3.grid()
ax3.legend(loc='center right', bbox_to_anchor=(0.95,0.5))


fig.supxlabel(r"$\mu$")
fig.supylabel("Error")


fig.savefig(impath + "Parameter_sweep_study_S" + ".png", format='png',dpi=200, transparent=True)
fig.savefig(impath + "Parameter_sweep_study_S" + ".pdf", format='pdf',dpi=200, transparent=True, bbox_inches="tight")
