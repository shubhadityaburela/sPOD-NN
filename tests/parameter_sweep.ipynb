# %%
import numpy as np
import matplotlib.pyplot as plt
from Helper import save_fig
import pandas as pd
import os

impath = "../plots/"
os.makedirs(impath, exist_ok=True) 

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern"]})

SMALL_SIZE = 16   # 16
MEDIUM_SIZE = 18   # 18
BIGGER_SIZE = 20   # 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
beta = np.asarray([542, 544, 546, 548, 552, 554, 556, 558, 562, 564, 566, 568, 572, 574, 576, 578])

err_sPOD_T_1D = np.asarray([0.0836, 0.1007, 0.1016, 0.0728, 0.0450, 0.0540, 0.0495, 0.0400, 0.0735, 0.1081, 0.1100, 0.0797, 0.0634, 0.0795, 0.0798, 0.0641])
err_I_T_1D = np.asarray([0.0481, 0.0734, 0.0733, 0.0481, 0.0458, 0.0698, 0.0697, 0.0457, 0.0447, 0.0681, 0.0681, 0.0447, 0.0473, 0.0721, 0.0721, 0.0473])
err_POD_T_1D = np.asarray([0.1433, 0.1417, 0.1405, 0.1397, 0.1386, 0.1382, 0.1379, 0.1377, 0.1376, 0.1377, 0.1378, 0.1380, 0.1384, 0.1385, 0.1386, 0.1386])

err_sPOD_T_2D = np.asarray([0.05958, 0.07720, 0.07248, 0.04677, 0.02698, 0.03737, 0.03243, 0.02052, 0.02401, 0.03179, 0.03134, 0.02443, 0.03446, 0.04924, 0.05103, 0.03539])
err_I_T_2D = np.asarray([0.04443, 0.06785, 0.06807, 0.04489, 0.03552, 0.05401, 0.05411, 0.03573, 0.02337, 0.03536, 0.03542, 0.02349, 0.03172, 0.04816, 0.04825, 0.03190])
err_POD_T_2D = np.asarray([0.09980, 0.09862, 0.09823, 0.09796, 0.09827, 0.09875, 0.09828, 0.09826, 0.09847, 0.09833, 0.09896, 0.09894, 0.09970, 0.10018, 0.10022, 0.10038])

err_sPOD_T_2DNL = np.asarray([0.03224, 0.03365, 0.03317, 0.03046, 0.03218, 0.03282, 0.03212, 0.02889, 0.02891, 0.03118, 0.03099, 0.02891, 0.02858, 0.03030, 0.03088, 0.03044])
err_I_T_2DNL = np.asarray([0.03033, 0.03320, 0.03322, 0.03040, 0.03113, 0.03313, 0.03197, 0.02826, 0.02872, 0.03087, 0.03026, 0.02725, 0.02775, 0.03018, 0.03041, 0.02911])
err_POD_T_2DNL = np.asarray([0.08033, 0.07805, 0.07585, 0.07395, 0.07148, 0.07102, 0.07114, 0.07161, 0.07161, 0.07216, 0.07267, 0.07338, 0.07610, 0.07818, 0.08003, 0.08207])

err_sPOD_S_1D = np.asarray([0.0108, 0.0146, 0.0135, 0.0087, 0.0076, 0.0109, 0.0104, 0.0087, 0.0100, 0.0152, 0.0155, 0.0110, 0.0074, 0.0131, 0.0154, 0.0123])
err_I_S_1D = np.asarray([0.0104, 0.0158, 0.0158, 0.0103, 0.0099, 0.0150, 0.0150, 0.0098, 0.0096, 0.0146, 0.0146, 0.0095, 0.0100, 0.0153, 0.0153, 0.0100])
err_POD_S_1D = np.asarray([0.0285, 0.0282, 0.0281, 0.0280, 0.0279, 0.0279, 0.0279, 0.0278, 0.0278, 0.0277, 0.0277, 0.0276, 0.0276, 0.0276, 0.0275, 0.0275])

err_sPOD_S_2D = np.asarray([0.01398, 0.01630, 0.01335, 0.00911, 0.00848, 0.00933, 0.00939, 0.00896, 0.00822, 0.00899, 0.00889, 0.00821, 0.00870, 0.01062, 0.01172, 0.01069])
err_I_S_2D = np.asarray([0.01043, 0.01462, 0.01460, 0.01039, 0.00885, 0.01199, 0.01199, 0.00885, 0.00709, 0.00884, 0.00883, 0.00708, 0.00814, 0.01073, 0.01071, 0.00809])
err_POD_S_2D = np.asarray([0.03311, 0.03263, 0.03226, 0.03203, 0.03171, 0.03170, 0.03167, 0.03158, 0.03158, 0.03154, 0.03149, 0.03145, 0.03132, 0.03129, 0.03122, 0.03117])

err_sPOD_S_2DNL = np.asarray([0.01738, 0.01689, 0.01673, 0.01687, 0.01764, 0.01803, 0.01826, 0.01830, 0.01791, 0.01752, 0.01703, 0.01656, 0.01603, 0.01627, 0.01707, 0.01796])
err_I_S_2DNL = np.asarray([0.01714, 0.01661, 0.01650, 0.01669, 0.01752, 0.01790, 0.01814, 0.01822, 0.01789, 0.01753, 0.01712, 0.01668, 0.01625, 0.01649, 0.01709, 0.01812])
err_POD_S_2DNL = np.asarray([0.02350, 0.02307, 0.02273, 0.02245, 0.02206, 0.02193, 0.02182, 0.02173, 0.02162, 0.02158, 0.02157, 0.02158, 0.02174, 0.02190, 0.02212, 0.02240])

# %%
fig = plt.figure(figsize=(14, 10), constrained_layout=True)
(subfig_t, subfig_b) = fig.subfigures(2, 1, hspace=0.05, wspace=0.1)

gs_t = subfig_t.add_gridspec(nrows=1, ncols=4)
ax1 = subfig_t.add_subplot(gs_t[0, 1:3])

ax1.plot(beta, err_sPOD_T_1D, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}_{\mathrm{tot}}$")
ax1.plot(beta, err_I_T_1D, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}_{\mathrm{tot}}$")
ax1.plot(beta, err_POD_T_1D, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}_{\mathrm{tot}}$")
ax1.set_title("Temperature (1D without wind)")
ax1.grid()
ax1.legend(loc='upper right', bbox_to_anchor=(0.55,0.8))



gs_b = subfig_b.add_gridspec(nrows=1, ncols=4)
ax2 = subfig_b.add_subplot(gs_b[0, 0:2])
ax3 = subfig_b.add_subplot(gs_b[0, 2:4], sharex=ax2)

ax2.plot(beta, err_sPOD_T_2D, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}_{\mathrm{tot}}$")
ax2.plot(beta, err_I_T_2D, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}_{\mathrm{tot}}$")
ax2.plot(beta, err_POD_T_2D, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}_{\mathrm{tot}}$")
ax2.set_title("Temperature (2D without wind)")
ax2.grid()
ax2.legend(loc='upper right', bbox_to_anchor=(0.99,0.9))

ax3.plot(beta, err_sPOD_T_2DNL, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}_{\mathrm{tot}}$")
ax3.plot(beta, err_I_T_2DNL, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}_{\mathrm{tot}}$")
ax3.plot(beta, err_POD_T_2DNL, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}_{\mathrm{tot}}$")
ax3.set_title("Temperature (2D with wind)")
ax3.grid()
ax3.legend(loc='center right', bbox_to_anchor=(0.95,0.6))


fig.supxlabel(r"$\mu$")
fig.supylabel("Error")

# save_fig(filepath=impath + 'Parameter_sweep_study_T', figure=fig)
fig.savefig(impath + "Parameter_sweep_study_T" + ".png", format='png',dpi=600, transparent=True)

# %%
fig = plt.figure(figsize=(14, 10), constrained_layout=True)
(subfig_t, subfig_b) = fig.subfigures(2, 1, hspace=0.05, wspace=0.1)

gs_t = subfig_t.add_gridspec(nrows=1, ncols=4)
ax1 = subfig_t.add_subplot(gs_t[0, 1:3])

ax1.plot(beta, err_sPOD_S_1D, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}_{\mathrm{tot}}$")
ax1.plot(beta, err_I_S_1D, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}_{\mathrm{tot}}$")
ax1.plot(beta, err_POD_S_1D, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}_{\mathrm{tot}}$")
ax1.set_title("Supply mass fraction (1D without wind)")
ax1.grid()
ax1.legend(loc='upper right', bbox_to_anchor=(0.95,0.8))



gs_b = subfig_b.add_gridspec(nrows=1, ncols=4)
ax2 = subfig_b.add_subplot(gs_b[0, 0:2])
ax3 = subfig_b.add_subplot(gs_b[0, 2:4], sharex=ax2)

ax2.plot(beta, err_sPOD_S_2D, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}_{\mathrm{tot}}$")
ax2.plot(beta, err_I_S_2D, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}_{\mathrm{tot}}$")
ax2.plot(beta, err_POD_S_2D, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}_{\mathrm{tot}}$")
ax2.set_title("Supply mass fraction (2D without wind)")
ax2.grid()
ax2.legend(loc='upper right', bbox_to_anchor=(0.99,0.9))

ax3.plot(beta, err_sPOD_S_2DNL, color="red", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-NN}}_{\mathrm{tot}}$")
ax3.plot(beta, err_I_S_2DNL, color="blue", linestyle='--', marker="*", label=r"$E^{\mathrm{sPOD-I}}_{\mathrm{tot}}$")
ax3.plot(beta, err_POD_S_2DNL, color="black", linestyle='--', marker="*", label=r"$E^{\mathrm{POD-NN}}_{\mathrm{tot}}$")
ax3.set_title("Supply mass fraction (2D with wind)")
ax3.grid()
ax3.legend(loc='center right', bbox_to_anchor=(0.95,0.5))


fig.supxlabel(r"$\mu$")
fig.supylabel("Error")


# save_fig(filepath=impath + 'Parameter_sweep_study_S', figure=fig)
fig.savefig(impath + "Parameter_sweep_study_S" + ".png", format='png',dpi=600, transparent=True)
